# %% [markdown]
# ## libraries

# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras.datasets import mnist, fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import partial

# %% [markdown]
# ## initial settings

# %%
num_classes = 10 #defined from datasets
epochs = 30 #more epochs than the none permuteted because 10 are not enough
validation_size = 0.1

# %% [markdown]
# ## define functions

# %% [markdown]
# ### permute data

# %%
def permuate_data(x):
    for i in range(len(x)):
        x[i] = np.random.permutation(x[i])
        for j in range(len(x[i])):
            x[i][j] = np.random.permutation(x[i][j])
    return x

# %% [markdown]
# ### train test split

# %%
def splitData(dataset):
  (X_train, y_train), (X_test, y_test) = dataset.load_data()

  X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=validation_size)

  X_train = X_train.reshape(int(60000 * (1.0 - validation_size)), 28, 28, 1)
  X_test = X_test.reshape(10000, 28, 28, 1)
  X_valid = X_valid.reshape(int(60000 * validation_size), 28, 28, 1)

  X_train = X_train.astype('float32')
  X_test = X_test.astype('float32')
  X_valid = X_valid.astype('float32')

  X_train /= 255
  X_test /= 255
  X_valid /= 255

  # convert class vectors to binary class matrices
  y_train = keras.utils.to_categorical(y_train, num_classes)
  y_test = keras.utils.to_categorical(y_test, num_classes)
  y_valid = keras.utils.to_categorical(y_valid, num_classes)


  X_train = permuate_data(X_train)
  X_test = permuate_data(X_test)
  X_valid = permuate_data(X_valid)

  return X_train, y_train, X_test, y_test, X_valid, y_valid

# %% [markdown]
# ### train model

# %%
def trainModel(model, X_train, y_train, X_valid, y_valid, optim='sgd'):
    model.compile(loss="categorical_crossentropy",
    optimizer="sgd",
    metrics=["accuracy"])
    
    #track epoch loss history
    history = model.fit(X_train, y_train, epochs=epochs,
                        validation_data=(X_valid, y_valid))
    
    return history

# %% [markdown]
# ### plot loss over epochs

# %%
def pltHistory(history):
  pd.DataFrame(history.history).plot(figsize=(8, 5))
  plt.grid(True)
  plt.gca().set_ylim(0, 2.5) # set the vertical range to [0-3]
  plt.title("Loss and Accuracy over Epochs")
  plt.xlabel('Epochs')
  plt.ylabel('Loss/Accuracy')
  plt.show()

# %% [markdown]
# ### execute experiments for a given model and dataset

# %%
def doExperiment(model, dataset, plot_hist=True):
  X_train, y_train, X_test, y_test, X_valid, y_valid = splitData(dataset)
  # print("--- Training Model ...")
  history = trainModel(model, X_train, y_train, X_valid, y_valid)
  if plot_hist == True:
    print("\n\n ========= History =========")
    pltHistory(history)
  print("\n\n ========= Evaluation (Loss, Accuracy) ========= ")
  return model.evaluate(X_test, y_test)

# %% [markdown]
# ## mlp

# %%
mlp_model = keras.models.Sequential([
  keras.layers.Flatten(input_shape=[28, 28, 1]),
  keras.layers.Dense(300, activation="relu"),
  keras.layers.Dense(100, activation="relu"),
  keras.layers.Dense(10, activation="softmax")
])

# %% [markdown]
# ### mnist dataset

# %%
doExperiment(mlp_model, mnist, plot_hist=True)
# Out:
# Epoch 1/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 2.2115 - accuracy: 0.2376 - val_loss: 1.8916 - val_accuracy: 0.2993
# Epoch 2/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1
30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1236 - accuracy: 0.9895 - val_loss: 5.6330 - val_accuracy: 0.2590
#
#
#  ========= History =========
#  ========= Evaluation (Loss, Accuracy) =========
# 313/313 [==============================] - 0s 2ms/step - loss: 5.5130 - accuracy: 0.2666
# [5.512950420379639, 0.26660001277923584]

# %% [markdown]
# ### fashion mnist

# %%
doExperiment(mlp_model, fashion_mnist, plot_hist=True)
# Out:
# Epoch 1/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 2.1767 - accuracy: 0.3703 - val_loss: 1.3889 - val_accuracy: 0.4438
# Epoch 2/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.3134 - accuracy: 0.4679 - val_loss: 1.3434 - val_accuracy: 0.4672
# Epoch 3/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.2436 - accuracy: 0.4950 - val_loss: 1.3659 - val_accuracy: 0.4487
# Epoch 4/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.2021 - accuracy: 0.5153 - val_loss: 1.2992 - val_accuracy: 0.4840
# Epoch 5/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.1629 - accuracy: 0.5295 - val_loss: 1.3317 - val_accuracy: 0.4885
# Epoch 6/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.1211 - accuracy: 0.5477 - val_loss: 1.3023 - val_accuracy: 0.4937
# Epoch 7/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.0944 - accuracy: 0.5594 - val_loss: 1.2989 - val_accuracy: 0.4930
# Epoch 8/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.0539 - accuracy: 0.5733 - val_loss: 1.3057 - val_accuracy: 0.4995
# Epoch 9/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.0197 - accuracy: 0.5880 - val_loss: 1.3110 - val_accuracy: 0.4903
# Epoch 10/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 1.0030 - accuracy: 0.5950 - val_loss: 1.3488 - val_accuracy: 0.5008
# Epoch 11/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.9677 - accuracy: 0.6098 - val_loss: 1.3365 - val_accuracy: 0.5047
# Epoch 12/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.9366 - accuracy: 0.6275 - val_loss: 1.3808 - val_accuracy: 0.4943
# Epoch 13/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.9025 - accuracy: 0.6412 - val_loss: 1.3884 - val_accuracy: 0.4908
# Epoch 14/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.8700 - accuracy: 0.6547 - val_loss: 1.4328 - val_accuracy: 0.4973
# Epoch 15/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.8409 - accuracy: 0.6683 - val_loss: 1.5728 - val_accuracy: 0.4970
# Epoch 16/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.8035 - accuracy: 0.6856 - val_loss: 1.5172 - val_accuracy: 0.4830
# Epoch 17/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.7791 - accuracy: 0.6968 - val_loss: 1.6838 - val_accuracy: 0.4910
# Epoch 18/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.7491 - accuracy: 0.7095 - val_loss: 1.7020 - val_accuracy: 0.4877
# Epoch 19/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.7221 - accuracy: 0.7210 - val_loss: 1.6529 - val_accuracy: 0.4873
# Epoch 20/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.6896 - accuracy: 0.7318 - val_loss: 1.6954 - val_accuracy: 0.4793
# Epoch 21/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.6660 - accuracy: 0.7462 - val_loss: 1.8147 - val_accuracy: 0.4873
# Epoch 22/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.6372 - accuracy: 0.7560 - val_loss: 1.8638 - val_accuracy: 0.4872
# Epoch 23/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.6076 - accuracy: 0.7697 - val_loss: 2.1427 - val_accuracy: 0.4747
# Epoch 24/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.5825 - accuracy: 0.7806 - val_loss: 2.1011 - val_accuracy: 0.4892
# Epoch 25/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.5588 - accuracy: 0.7914 - val_loss: 1.9153 - val_accuracy: 0.4778
# Epoch 26/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.5358 - accuracy: 0.8023 - val_loss: 2.1761 - val_accuracy: 0.4800
# Epoch 27/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.5146 - accuracy: 0.8119 - val_loss: 2.1405 - val_accuracy: 0.4875
# Epoch 28/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.4854 - accuracy: 0.8265 - val_loss: 2.1189 - val_accuracy: 0.4818
# Epoch 29/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.4673 - accuracy: 0.8359 - val_loss: 2.2781 - val_accuracy: 0.4808
# Epoch 30/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.4428 - accuracy: 0.8482 - val_loss: 2.1794 - val_accuracy: 0.4820
#
#
#  ========= History =========
#  ========= Evaluation (Loss, Accuracy) =========
# 313/313 [==============================] - 1s 2ms/step - loss: 2.1812 - accuracy: 0.4684
# [2.181215524673462, 0.4684000015258789]

# %% [markdown]
# ## cnn

# %%
DefaultConv2D = partial(keras.layers.Conv2D, kernel_size=3, activation='relu', padding="SAME")

cnn_model = keras.models.Sequential([
DefaultConv2D(filters=64, kernel_size=7, input_shape=[28, 28, 1]),
keras.layers.MaxPooling2D(pool_size=2),
DefaultConv2D(filters=128),
DefaultConv2D(filters=128),
keras.layers.MaxPooling2D(pool_size=2),
DefaultConv2D(filters=256),
DefaultConv2D(filters=256),
keras.layers.MaxPooling2D(pool_size=2),
keras.layers.Flatten(),
keras.layers.Dense(units=128, activation='relu'),
keras.layers.Dropout(0.5),
keras.layers.Dense(units=64, activation='relu'),
keras.layers.Dropout(0.5),
keras.layers.Dense(units=10, activation='softmax'),
])

# %% [markdown]
# ### mnist

# %%
doExperiment(cnn_model, mnist)
# Out:
# Epoch 1/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 2.2905 - accuracy: 0.1361 - val_loss: 2.1450 - val_accuracy: 0.2095
# Epoch 2/30
# 1688/1688 [==============================] - 63s 37ms/step - loss: 2.1619 - accuracy: 0.2020 - val_loss: 2.0907 - val_accuracy: 0.2203
# Epoch 3/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 2.1068 - accuracy: 0.2154 - val_loss: 2.0169 - val_accuracy: 0.2480
# Epoch 4/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 2.0733 - accuracy: 0.2259 - val_loss: 2.0752 - val_accuracy: 0.2352
# Epoch 5/30
# 1688/1688 [==============================] - 65s 39ms/step - loss: 2.0468 - accuracy: 0.2375 - val_loss: 1.9559 - val_accuracy: 0.2747
# Epoch 6/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 2.0082 - accuracy: 0.2528 - val_loss: 1.8802 - val_accuracy: 0.2990
# Epoch 7/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 1.9197 - accuracy: 0.2908 - val_loss: 1.8019 - val_accuracy: 0.3430
# Epoch 8/30
# 1688/1688 [==============================] - 67s 39ms/step - loss: 1.8229 - accuracy: 0.3233 - val_loss: 1.7005 - val_accuracy: 0.3632
# Epoch 9/30
# 1688/1688 [==============================] - 67s 40ms/step - loss: 1.7786 - accuracy: 0.3406 - val_loss: 1.6667 - val_accuracy: 0.3708
# Epoch 28/30
# 1688/1688 [==============================] - 70s 41ms/step - loss: 1.5375 - accuracy: 0.4119 - val_loss: 1.4894 - val_accuracy: 0.4283
# Epoch 29/30
# 1688/1688 [==============================] - 72s 42ms/step - loss: 1.5326 - accuracy: 0.4114 - val_loss: 1.5081 - val_accuracy: 0.4197
# Epoch 30/30
# 1688/1688 [==============================] - 74s 44ms/step - loss: 1.5093 - accuracy: 0.4203 - val_loss: 1.5004 - val_accuracy: 0.4140
#
#
#  ========= History =========
#  ========= Evaluation (Loss, Accuracy) =========
# 313/313 [==============================] - 4s 14ms/step - loss: 1.4973 - accuracy: 0.4218
# [1.4973286390304565, 0.42179998755455017]

# %% [markdown]
# ### fashion mnist

# %%
doExperiment(cnn_model, fashion_mnist)
# Out:
# Epoch 1/30
# 1688/1688 [==============================] - 71s 41ms/step - loss: 1.8938 - accuracy: 0.3393 - val_loss: 1.2900 - val_accuracy: 0.5167
# Epoch 2/30
# 1688/1688 [==============================] - 69s 41ms/step - loss: 1.3392 - accuracy: 0.4872 - val_loss: 1.2160 - val_accuracy: 0.5268
# Epoch 3/30
# 1688/1688 [==============================] - 68s 40ms/step - loss: 1.2782 - accuracy: 0.5098 - val_loss: 1.1495 - val_accuracy: 0.5350
# Epoch 4/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 1.2329 - accuracy: 0.5228 - val_loss: 1.1069 - val_accuracy: 0.5767
# Epoch 5/30
# 1688/1688 [==============================] - 62s 37ms/step - loss: 1.2075 - accuracy: 0.5401 - val_loss: 1.1178 - val_accuracy: 0.5655
# Epoch 6/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 1.1712 - accuracy: 0.5484 - val_loss: 1.0962 - val_accuracy: 0.5717
# Epoch 7/30
# 1688/1688 [==============================] - 65s 38ms/step - loss: 1.1524 - accuracy: 0.5597 - val_loss: 1.0806 - val_accuracy: 0.5822
# Epoch 8/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 1.1237 - accuracy: 0.5703 - val_loss: 1.0614 - val_accuracy: 0.5933
# Epoch 9/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 1.1162 - accuracy: 0.5759 - val_loss: 1.1235 - val_accuracy: 0.5557
# Epoch 10/30
# 1688/1688 [==============================] - 65s 38ms/step - loss: 1.0911 - accuracy: 0.5816 - val_loss: 1.0078 - val_accuracy: 0.6057
# Epoch 11/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 1.0728 - accuracy: 0.5928 - val_loss: 1.0000 - val_accuracy: 0.6147
# Epoch 12/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 1.0577 - accuracy: 0.5976 - val_loss: 0.9782 - val_accuracy: 0.6175
# Epoch 13/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 1.0318 - accuracy: 0.6044 - val_loss: 1.0020 - val_accuracy: 0.6090
# Epoch 14/30
# 1688/1688 [==============================] - 65s 39ms/step - loss: 1.0238 - accuracy: 0.6086 - val_loss: 1.1030 - val_accuracy: 0.5822
# Epoch 15/30
# 1688/1688 [==============================] - 65s 39ms/step - loss: 1.0069 - accuracy: 0.6129 - val_loss: 0.9715 - val_accuracy: 0.6162
# Epoch 16/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 0.9929 - accuracy: 0.6168 - val_loss: 0.9754 - val_accuracy: 0.6203
# Epoch 17/30
# 1688/1688 [==============================] - 65s 39ms/step - loss: 0.9760 - accuracy: 0.6241 - val_loss: 1.0156 - val_accuracy: 0.6078
# Epoch 18/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 0.9797 - accuracy: 0.6265 - val_loss: 1.0110 - val_accuracy: 0.6142
# Epoch 19/30
# 1688/1688 [==============================] - 66s 39ms/step - loss: 0.9670 - accuracy: 0.6306 - val_loss: 0.9673 - val_accuracy: 0.6210
# Epoch 20/30
# 1688/1688 [==============================] - 64s 38ms/step - loss: 0.9536 - accuracy: 0.6337 - val_loss: 0.9303 - val_accuracy: 0.6390
# Epoch 21/30
# 1688/1688 [==============================] - 59s 35ms/step - loss: 0.9380 - accuracy: 0.6377 - val_loss: 0.9337 - val_accuracy: 0.6397
# Epoch 22/30
# 1688/1688 [==============================] - 60s 35ms/step - loss: 0.9245 - accuracy: 0.6467 - val_loss: 0.9303 - val_accuracy: 0.6333
# Epoch 23/30
# 1688/1688 [==============================] - 60s 36ms/step - loss: 0.9114 - accuracy: 0.6475 - val_loss: 0.9285 - val_accuracy: 0.6348
# Epoch 24/30
# 1688/1688 [==============================] - 61s 36ms/step - loss: 0.9039 - accuracy: 0.6531 - val_loss: 0.9383 - val_accuracy: 0.6303
# Epoch 25/30
# 1688/1688 [==============================] - 61s 36ms/step - loss: 0.8909 - accuracy: 0.6598 - val_loss: 0.9941 - val_accuracy: 0.6175
# Epoch 26/30
# 1688/1688 [==============================] - 60s 36ms/step - loss: 0.8766 - accuracy: 0.6561 - val_loss: 0.9221 - val_accuracy: 0.6400
# Epoch 27/30
# 1688/1688 [==============================] - 60s 36ms/step - loss: 0.8579 - accuracy: 0.6635 - val_loss: 0.9951 - val_accuracy: 0.6240
# Epoch 28/30
# 1688/1688 [==============================] - 60s 36ms/step - loss: 0.8466 - accuracy: 0.6739 - val_loss: 1.0374 - val_accuracy: 0.6130
# Epoch 29/30
# 1688/1688 [==============================] - 60s 36ms/step - loss: 0.8190 - accuracy: 0.6781 - val_loss: 0.9587 - val_accuracy: 0.6347
# Epoch 30/30
# 1688/1688 [==============================] - 60s 36ms/step - loss: 0.8133 - accuracy: 0.6815 - val_loss: 0.9846 - val_accuracy: 0.6272
#
#
#  ========= History =========
#  ========= Evaluation (Loss, Accuracy) =========
# 313/313 [==============================] - 3s 10ms/step - loss: 1.0131 - accuracy: 0.6256
# [1.0131471157073975, 0.6255999803543091]
